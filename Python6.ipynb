# %% [markdown]
# **String** **Metodları**
#   kalın metin

# %% [markdown]
# ## Changing metod = Değiştirme yöntemleri

# %%
# Upper metodu, karakterleri büyük harfe çevirir.
sentence2 = " I live and work in, Virginia"
sentence2 = sentence2.upper()
print(sentence2)
# Out:
#  I LIVE AND WORK IN, VIRGINIA

# %%
# Lower metodu, karakterleri küçük harfe çevirir.
sentence3 = " I live and work in, Virginia"
sentence3 = sentence3.lower()
print(sentence3)
# Out:
#  i live and work in, virginia

# %%
# Title metodu, karakter dizisindeki her kelimenin baş harfini küçük harfe çevirir.
sentence4 = " I live and work in, Virginia"
sentence4 = sentence4.lower()
print(sentence3)
# Out:
#  i live and work in, virginia

# %%
# Capitalize, karakter dizisindeki sadece ilk kelimenin baş harfini büyük harfe çevirir.
sentence5 = "merhaba"
sentence5 = sentence5.capitalize()
print(sentence5)
# Out:
# Merhaba

# %%
# Replace metodu karakter güncellemesi için kullanılır. 
sentece6 = "My name is vuslat"
sentece6 = sentece6.replace("vuslat", "mehmet")
sentence1 = "0yayı 0yala"
sentence1 = sentence1.replace("0", "o") # o harfi yerine 0 sıfır rakamı kullanılmış
print(sentece6, sentence1)
# Out:
# My name is mehmet oyayı oyala

# %%
# Bu metot eğer harf küçük ise büyük harfe çevirir eğer büyükse küçük harfe çevirir.
sentece7 = "MeRhAbA bU gÜzEl"
sentece7 = sentece7.swapcase()
sentece8 = "ESKİSİ gibi"
sentece8 = sentece8.swapcase()
print(sentece7, sentece8)
# Out:
# mErHaBa Bu GüZeL eski̇si̇ GIBI

# %% [markdown]
# #Editing a String = Dize düzenleme

# %%
# string.strip() metodu başından ve sonundan olan boşlukları ve escape sequenceleri sıfırlar
space_string = "       listen first   "
print(space_string.strip())
# Out:
# listen first

# %%
space_string = "\n       listen first   \t"
print(space_string.strip())
# Out:
# listen first

# %%
# string.rstrip() metodu sağdan olan boşlukları ve escape sequenceleri sıfırlar sıfırlar
space_string = "\n       listen first   "
print(space_string.rstrip())
# Out:
#        listen first

# %%
# string.lstrip() metodu soldan olan boşlukları ve escape sequenceleri sıfırlar sıfırlar
space_string = "       listen first   \t"
print(space_string.lstrip())
# Out:
# listen first

# %%
# Örnekler
# strip metodu baştan ve sondan "i" "iy" "yi" "y" kobinasyonlarını dener ve uyanları kaldıdır
source_string = "interopebiliyt"
source2_string = "imteropebiliy"
print(source_string.strip("yi"))
print(source2_string.strip("yim")) # Harf sayısı farketmeksizin bütün kombinasyonları dener
# Out:
# nteropebiliyt
# teropebil

# %%
# örnek
text = 'tyou can learn almost everything in pre-classz'
text = text.strip("tz").upper()
print(text)
# Out:
# YOU CAN LEARN ALMOST EVERYTHING IN PRE-CLASS

# %%
# --örnek--
# burada f döndürme kullanılmıştır
#    123456789
f = "ın good wee trust"
f1 = f[:9]
f2 = f[-7:]
print(f1+f2)
# Out:
# ın good we trust

# %%
# --örnek--
# burada replace kullanılmıştır
text1 = 'ın good wee trust'
print(text1.replace('ee', 'e'))
# Out:
# ın good we trust

# %% [markdown]
# #**COLLECTİON TYPES**

# %% [markdown]
# ## List

# %% [markdown]
# ### Creating a List = Liste oluşturma

# %% [markdown]
# list.()
#
# [ ]

# %%
# [] her çeşit veriyi alır

# %%
# list() 1- İçeriye iterable veriyi alır 
# 2. İterable veriyi elemanlara ayırıyor 
# 3. Baştan sona kadar virgül koyar
# 4. İterable elemanlarının sonunda listenin elemanı halie getiriyor

# %%
list("clarusway") # list fonsiyonunu elemanlarına ayırdı ve ----> [] listeye aktardı
# Out:
# ['c', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y']

# %%
a = [1, 2, 3, 4]
list(a)
# Out:
# [1, 2, 3, 4]

# %%
list_1 = ['h', 'a', 'p', 'p', 'y']
world = "happy"
list_2 = list(world)
print(list_1)
print(list_2)
# Out:
# ['h', 'a', 'p', 'p', 'y']
# ['h', 'a', 'p', 'p', 'y']

# %%
list(1234) # hata vericek iterable olmadığı için
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1d46027d1a4e> in <module>()
# ----> 1 list(1234)
#
# TypeError: 'int' object is not iterable

# %%
string_1 = "I quit smoking" #boşluklar da dahil elemanlarına ayırdı 
new_list_1 = list(string_1)
print(new_list_1)

new_list_2 = [string_1] # İçerisine ne yazılırsa elemanlar o olur
print(new_list_2)
# Out:
# ['I', ' ', 'q', 'u', 'i', 't', ' ', 's', 'm', 'o', 'k', 'i', 'n', 'g']
# ['I quit smoking']

# %%
mixed_list = [11, 'Joseph', False, 3.14, None, [1, 2, 3]]
             #int,  str,    bool,   float, noe type, list,
             #Bir listeninin bileşenleri farklı çeşitler barındırabilir 
print(mixed_list)
# Out:
# [11, 'Joseph', False, 3.14, None, [1, 2, 3]]

# %%
my_list = ['Joseph', 'Clarusway', 2020] 
new_list1 = list(my_list)
new_list2 = [my_list] # my listi manuel olarak [] parantezinin içerisine koydu 

print(new_list1) # my listin list fonsiyonu
print(len(new_list1)) # len fonsiyonu saydırdığı için new listi sayarak 3 cevabını verir
print(new_list2) 
print(len(new_list2))
# Out:
# ['Joseph', 'Clarusway', 2020]
# 3
# [['Joseph', 'Clarusway', 2020]]
# 1

# %%
mesela = [[1,2,4],False, "ali", 11, ["veli", ["deli"]]]
len(mesela)
# Out:
# 5

# %%
len([[[" "]]])
# Out:
# 1

# %% [markdown]
# ### Basic Operations with Lists=Listelerle Temel İşlemler

# %% [markdown]
# .append()
#
# .pop()
#
# .insert()
#
# .remove()
#
# .sort()
#
#    ord() karakterin aski sıralamsını vercek hep "" str olarak sorulacak
#
#    chr() aski kodu verilen karakteri bize söyler

# %%
# Boş liste örnekleri
[]
list()
# Out:
# []

# %%
# .append() listenin sonun eleman ekler
listem = []

# %%
# ÖRNEK
listem.append(11) # listem ekleme yapacak 
# her çalıştırmada ekleme yapcaktır

# %%
# ÖRNEK
listem.append(True)
listem
# Out:
# [11, 11, 11, 11, 11, True]

# %%
# ÖRNEK
listem.append("merhaba")
listem
# Out:
# [11, 11, 11, 11, 11, True, 'merhaba']

# %%
# ÖRNEK
listem.append(3.14)
listem
# Out:
# [11, 11, 11, 11, 11, True, 'merhaba', 3.14]

# %%
# ÖRNEK
# -1 elemanı döndğrecek yani sol taraf tan yazılan indexi silecek
listem.pop() # son elemanı return remove edecek
# Out:
# 3.14

# %%
# ÖRNEK
listem # son elemanı sildi
# Out:
# [11, 11, 11, 11, 11, True, 'merhaba']

# %%
# ÖRNEK
listem.pop(1) # 1. indexi sildi ve bunu sildiğinin çıktı verdi
# Out:
# 11

# %%
# ÖRNEK
listem # Çıktıda silinen değeri düşüp son kalan stringi bize çıktı verdi
# Out:
# [11, 11, True, 'merhaba']

# %%
# ÖRNEK
bir_list = []
bir_list.append(6666)
bir_list.append("multiverse")
bir_list.append([0])

print(bir_list)
# Out:
# [6666, 'multiverse', [0]]

# %%
## .insert hangi indexe eleman eklemek istiyorsanız oraya ekleme yapar
# belirtilen index konumu ne ise atamayı sağlayacaktır

# %%
iki_list = ["ahmet", "deli", 22]
          #    0       1     2

# %%
iki_list.insert(2, "sezer") # 2 numaralı index yerine yanın 22 sağa kaydır dı sezer yazdı
iki_list
# Out:
# ['ahmet', 'deli', 'sezer', 22]

# %%
numbers = [1, 2, 3, 4]
        #  0  1  2  3 
        # -4 -3 -2 -1
numbers.insert(4, 5)
        # 4. index boş olduğundan dolayı son kısıma 5 i atadı

# %%
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers.insert(-3, "deneme")

# %%
print(numbers)
# Out:
# [1, 2, 'deneme', 3, 4, 5]

# %%
##.remove() silinmek istenilenn elemanın kendisini yazarak sileriz

# %%
numara = [1, 4, 7, 9]

# %%
numara.remove(7) # silmek istenilen eleman yazıldı
print(numara)
# Out:
# [1, 4, 9]

# %%
## .sort() metodu sıralam metodudu
# önce büyük harfler 
# alfabetik sıralam yani aski kodlara göre

# %%
yeni = [3, 5, 1, 7, 4]

# %%
yeni.sort()
yeni # çıktısından sort etmiş yani sıralamış oldu
# Out:
# [1, 3, 4, 5, 7]

# %%
isimler = ["yılmaz", "Zekai", "ibo", "ali", "veli"]

# %%
isimler.sort()
isimler 
    # çıktısında alfebedik sıraya görü çıktı verecek
    # fakat öenmli bir kural var büyük harfler önceliklidir
    # Zekai büyük harfle başladığından dolayı başa gelmektedir
# Out:
# ['Zekai', 'ali', 'ibo', 'veli', 'yılmaz']

# %%
denek_2 = ["d", 1, "a", 7] # sort sırlamasında ikisini aynı anda kullanamazsın
denek_2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d8522765ea1f> in <module>()
#       1 denek_2 = ["d", 1, "a", 7]
# ----> 2 denek_2.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
denek_3 = [1, 2 , 3, 4]
denek_4 = ["alif", "alip"]
denek_3.sort()
denek_4.sort()

# %%
print(denek_3 + denek_4)
# Out:
# [1, 2, 3, 4, 'alif', 'alip']

# %%
list1 = ["one", "nine", "four"]

# %%
list1.sort()

# %%
list1 # alfabetik sıralama ya göre çıktı aldı
# Out:
# ['four', 'nine', 'one']

# %%
list1.sort(reverse = True) # reverse true dediğimizde ters işleme almış oldu 
list1
# Out:
# ['one', 'nine', 'four']

# %%
list1.sort(reverse = False) # reverse false dediğimizde ters işlemi engelldi
list1
# Out:
# ['four', 'nine', 'one']

# %%
list3 = ["@", "*--", "false"]
list3.sort()

# %%
list3 # sıralamasını aski koda göre yapmış oldu 
# görülüyorki * aski kodda diğerlerine göre daha ön sırada
# Out:
# ['*--', '@', 'false']

# %%
ord("*")
# Out:
# 42

# %%
ord("@")
# Out:
# 64

# %%
list4 = [True, False] # true değeri 1 false 0 olma kuralı olduğundan dolayı 
# false başa gelecek true sona gelecek

# %%
list4.sort()
list4
#false=0
#true=1
# Out:
# [False, True]

# %%
# negatif değerlerde sort etme
list5 = [[3], [44], [-12]]
#negatif değer küçük olduğundna dolayı negatif değerden başlayacakdır

# %%
list5.sort()
list5
# Out:
# [[-12], [3], [44]]

# %%
# liste içerisinden bulunan listelerde ilk elemana göre sıralama söz konusudur
list6 = [[1,3], [44, -40], [-12, 1]]

# %%
list6.sort()
list6
# Out:
# [[-12, 1], [1, 3], [44, -40]]

# %%
chr(36) # ord işleminin tersi aski kod  sor karakter al
# Out:
# '$'

# %%
ord("$") # chr işleminin tersi karakter sor aski kod al
# Out:
# 36
